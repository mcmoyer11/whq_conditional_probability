# %%
import pandas as pd
from pandas import DataFrame
from sklearn.preprocessing import scale
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib as mpl 
import os
import csv

# %%
# Import the data vile
d = pd.read_csv("answer.csv")

# %%
like = d.loc[d["task"].isin(['likely'])]
accept = d.loc[d["task"].isin(['accept'])]

# %%
# for the nice dark blues, greens
#sns.set_palette("GnBu_d", 8, .75)
#sns.hls_palette(8, l=.3, s=.8)
# For beautiful greens
sns.set_palette(sns.cubehelix_palette(5, start=.75, rot=-.75))

# %%
# len(like) #1488
len(accept) #1367
# Out:
# 1367

# %%
# Trying to get the counts in there
sns.set(font_scale=2)
g = sns.catplot(x="likert", kind="count", col="task", hue="answer", palette="ch:.25", data=d, height=8.27, aspect=11.7/8.27)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Across Task')
plt.show()

# %%
# Trying to get the counts in there
g = sns.catplot(x="likert", kind="count", data=like, palette="ch:.25", height=8.27, aspect=11.7/8.27) #, palette="ch:.25"
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Likely Task')
plt.show()

# %%
# Try using seaborn to make a box plot
g = sns.boxplot(x="answer",y="likert",data=d,hue="modal")
g.set_title("Total Data")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
sns.violinplot(x="modal", y="likert", data=d, hue="wh")
g.set_title("Total Data")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
# Trying to add a facet for modals
g = sns.catplot(x="answer", y="likert", hue="modal", col="task", data=d, kind="box", palette="ch:.25", height=8.27, aspect=11.7/8.27)
g.set_title("Total Data")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.subplots_adjust(top=0.9)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-233153f66ac7> in <module>
#       1 # Trying to add a facet for modals
#       2 g = sns.catplot(x="answer", y="likert", hue="modal", col="task", data=d, kind="box", palette="ch:.25", height=8.27, aspect=11.7/8.27)
# ----> 3 g.set_title("Total Data")
#       4 plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#       5 plt.subplots_adjust(top=0.9)
#
# AttributeError: 'FacetGrid' object has no attribute 'set_title'

# %%
sns.catplot(x='answer', y='likert', hue='wh',col="modal",
            data=d, jitter='0.25')
plt.show()

# %%
sns.catplot(x="answer", y="likert", hue="modal", col="task", data=d, kind="boxen", palette="ch:.25", height=8.27, aspect=11.7/8.27)
plt.subplots_adjust(top=0.9)
plt.show()

# %%
g= sns.catplot(x="answer", y="likert", hue="modal", col="task", kind="violin", split=True, data=d)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('All Answers')
plt.show()

# %%
# MODAL FIRST SUBSET
d_mod = d.loc[d["modal"].isin(['mod'])]
d_nomod = d.loc[d["modal"].isin(['nomod'])]

# ANSWER FIRST SUBSET
d_MO = d.loc[d["answer"].isin(['MO'])]
d_MS = d.loc[d["answer"].isin(['MS'])]
d_MA = d.loc[d["answer"].isin(['MA'])]

# %%
# Trying to get the counts in there
g = sns.catplot(x="likert", kind="count", palette="ch:.25", data=d_MS)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('MS Answers')
plt.show()

# %%
g = sns.catplot(x="modal", y="likert", hue="wh",kind="boxen", col="task", data=d_MA, height=8.27, aspect=11.7/8.27)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('MA Answers')
plt.show()

# %%
# MODAL > WH
# mod
d_mod_who = d_mod.loc[d_mod["wh"].isin(['who'])]
d_mod_where = d_mod.loc[d_mod["wh"].isin(['where'])]
d_mod_how = d_mod.loc[d_mod["wh"].isin(['how'])]
# nomod
d_nomod_who = d_nomod.loc[d_nomod["wh"].isin(['who'])]
d_nomod_where = d_nomod.loc[d_nomod["wh"].isin(['where'])]
d_nomod_how = d_nomod.loc[d_nomod["wh"].isin(['how'])]

# MODAL > WH > ANSWER
# modal
d_mod_who_MO = d_mod_who.loc[d_mod_who["answer"].isin(['MO'])]
d_mod_where_MO = d_mod_where.loc[d_mod_where["answer"].isin(['MO'])]
d_mod_how_MO = d_mod_how.loc[d_mod_how["answer"].isin(['MO'])]

d_mod_who_MS = d_mod_who.loc[d_mod_who["answer"].isin(['MS'])]
d_mod_where_MS = d_mod_where.loc[d_mod_where["answer"].isin(['MS'])]
d_mod_how_MS = d_mod_how.loc[d_mod_how["answer"].isin(['MS'])]

d_mod_who_MA = d_mod_who.loc[d_mod_who["answer"].isin(['MA'])]
d_mod_where_MA = d_mod_where.loc[d_mod_where["answer"].isin(['MA'])]
d_mod_how_MA = d_mod_how.loc[d_mod_how["answer"].isin(['MA'])]

# no modal
d_nomod_who_MO = d_nomod_who.loc[d_nomod_who["answer"].isin(['MO'])]
d_nomod_where_MO = d_nomod_where.loc[d_nomod_where["answer"].isin(['MO'])]
d_nomod_how_MO = d_nomod_how.loc[d_nomod_how["answer"].isin(['MO'])]

d_nomod_who_MS = d_nomod_who.loc[d_nomod_who["answer"].isin(['MS'])]
d_nomod_where_MS = d_nomod_where.loc[d_nomod_where["answer"].isin(['MS'])]
d_nomod_how_MS = d_nomod_how.loc[d_nomod_how["answer"].isin(['MS'])]

d_nomod_who_MA = d_nomod_who.loc[d_nomod_who["answer"].isin(['MA'])]
d_nomod_where_MA = d_nomod_where.loc[d_nomod_where["answer"].isin(['MA'])]
d_nomod_how_MA = d_nomod_how.loc[d_nomod_how["answer"].isin(['MA'])]


# MODAL > ANSWER
#modal
d_mod_MO = d_mod.loc[d_mod["answer"].isin(['MO'])]
d_mod_MS = d_mod.loc[d_mod["answer"].isin(['MS'])]
d_mod_MA = d_mod.loc[d_mod["answer"].isin(['MA'])]
#nomodal
d_nomod_MO = d_nomod.loc[d_nomod["answer"].isin(['MO'])]
d_nomod_MS = d_nomod.loc[d_nomod["answer"].isin(['MS'])]
d_nomod_MA = d_nomod.loc[d_nomod["answer"].isin(['MA'])]

# %%
from __future__ import division
# Out:
# 0.39344262295081966

# %%
# Trying to get the counts in there
g = sns.catplot(x="likert", kind="count", col="task", palette="ch:.25", data=d_mod_who_MA)
plt.subplots_adjust(top=0.9)
g.fig.suptitle('Modal-Who MA Answers')
plt.show()

# %%
amo = sns.catplot(x="likert", y="modal", kind="boxen", col="task", data=d_MO, hue="wh")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.subplots_adjust(top=0.9)
amo.fig.suptitle('MO Answers')
plt.show()
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %%
#sns.barplot(x='group', y='Values', data=df, estimator=lambda x: sum(x==0)*1.0/len(x))

# %%
ams = sns.boxplot(x="likert", y="modal", data=d_MS, hue="wh")
ams.set_title("Mention-Some Answers")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
ama = sns.boxplot(x="likert", y="modal", data=d_MA, hue="wh")
ama.set_title("Mention-All Answers")
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
